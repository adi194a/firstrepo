# %%
import pandas as pd

# %%
# !pip install SQLAlchemy

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
conn = create_engine("mysql+pymysql://root:root@localhost:3306/offline6")

# %%
conn
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/offline6)

# %%
df = pd.read_sql_table("emp_new",conn)

# %%
pd.read_sql_query("select id,name,sal from emp_new where sal>75000",conn)
# Out:
#     id              name    sal
# 0    1      John Johnson  79626
# 1    3      Daniel Brown  83919
# 2    4       Sarah White  80068
# 3    7      Olivia White  78662
# 4    8        Emma Smith  76787
# 5    9       Sarah Davis  86448
# 6   15      Laura Taylor  81642
# 7   18        John Davis  78317
# 8   20      Sarah Wilson  85388
# 9   21      Emily Wilson  78968
# 10  23       Emma Wilson  82065
# 11  24       James Smith  85455
# 12  30     Michael White  85518
# 13  38  Michael Anderson  84230
# 14  41     Daniel Thomas  89005
# 15  43       Laura White  82474
# 16  44      James Thomas  82161
# 17  45       Laura Smith  87465
# 18  48     Daniel Taylor  85487
# 19  53      Olivia Smith  87685
# 20  54       Sarah Brown  84795
# 21  63      Daniel Brown  77106
# 22  78       Sarah Brown  78998
# 23  80        John Davis  83101
# 24  83       Sarah Smith  81948
# 25  88     Olivia Taylor  79379
# 26  91       David Brown  83923
# 27  92        Emma White  80412
# ...

# %%
import pymysql

# %%
conn = pymysql.connect(host='localhost',user='root',password='root',port=3306,database='offline6')

# %%
cur = conn.cursor()

# %%
cur.execute("update emp_new set sal=123 where name='John Johnson'")
conn.commit()

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1C20-1AA2
#
#  Directory of C:\Users\AI NEXUT IT\Desktop\pandas_6
#
# 10-09-2025  05:11    <DIR>          .
# 10-09-2025  02:17    <DIR>          ..
# 10-09-2025  04:59    <DIR>          .ipynb_checkpoints
# 09-09-2025  04:55         4,744,481 amazon.csv
# 09-09-2025  05:28         1,843,612 COVID-19 pandemic by country and territory - Wikipedia.html
# 09-09-2025  05:28    <DIR>          COVID-19 pandemic by country and territory - Wikipedia_files
# 09-09-2025  05:31             9,380 coviddata.csv
# 09-09-2025  05:32             9,091 edata.html
# 09-09-2025  05:17            11,207 empdata.xlsx
# 09-09-2025  04:58            24,155 employees.json
# 09-09-2025  05:33            65,141 Pandas-1.ipynb
# 10-09-2025  05:11            11,857 Untitled.ipynb
#                8 File(s)      6,718,924 bytes
#                4 Dir(s)  230,694,735,872 bytes free

# %%
df = pd.read_excel("empdata.xlsx")

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.to_sql(name="empdata1",
          con=conn,
          if_exists="append",
          index=False,
          chunksize=1000)
# Out:
# 4

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.to_excel("temptemptmeptet.xlsx",index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1C20-1AA2
#
#  Directory of C:\Users\AI NEXUT IT\Desktop\pandas_6
#
# 10-09-2025  05:21    <DIR>          .
# 10-09-2025  02:17    <DIR>          ..
# 10-09-2025  04:59    <DIR>          .ipynb_checkpoints
# 09-09-2025  04:55         4,744,481 amazon.csv
# 09-09-2025  05:28         1,843,612 COVID-19 pandemic by country and territory - Wikipedia.html
# 09-09-2025  05:28    <DIR>          COVID-19 pandemic by country and territory - Wikipedia_files
# 09-09-2025  05:31             9,380 coviddata.csv
# 09-09-2025  05:32             9,091 edata.html
# 09-09-2025  05:17            11,207 empdata.xlsx
# 09-09-2025  04:58            24,155 employees.json
# 09-09-2025  05:33            65,141 Pandas-1.ipynb
# 10-09-2025  05:15             5,073 temptemptmeptet.xlsx
# 10-09-2025  05:21            18,756 Untitled.ipynb
#                9 File(s)      6,730,896 bytes
#                4 Dir(s)  230,675,218,432 bytes free

# %%
df = pd.read_html("COVID-19 pandemic by country and territory - Wikipedia.html")

# %%
df = df[13]

# %%
df.to_sql(
# Out:
#   Cell In[51], line 1
#     df.to_sql(
#               ^
# SyntaxError: incomplete input

# %%
df.to_sql(name="covid",
          con=conn,
          if_exists="append",
          index=False,
          chunksize=1000)
# Out:
# 240

# %%
df = pd.read_sql_table("emp_new",conn)

# %%
df
# Out:
#      id             name    sal         city
# 0     1     John Johnson    123     San Jose
# 1     2    Laura Jackson  49031      Chicago
# 2     3     Daniel Brown  83919    San Diego
# 3     4      Sarah White  80068      Houston
# 4     5  Michael Jackson  53836      Chicago
# ..  ...              ...    ...          ...
# 95   96    Daniel Taylor  54419  San Antonio
# 96   97     Olivia Davis  46628      Houston
# 97   98     David Thomas  56998      Phoenix
# 98   99     Olivia Brown  79217      Houston
# 99  100      Laura Davis  62893  San Antonio
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (100, 4)

# %%
df.columns
# Out:
# Index(['id', 'name', 'sal', 'city'], dtype='object')

# %%
df
# Out:
#      id             name    sal         city
# 0     1     John Johnson    123     San Jose
# 1     2    Laura Jackson  49031      Chicago
# 2     3     Daniel Brown  83919    San Diego
# 3     4      Sarah White  80068      Houston
# 4     5  Michael Jackson  53836      Chicago
# ..  ...              ...    ...          ...
# 95   96    Daniel Taylor  54419  San Antonio
# 96   97     Olivia Davis  46628      Houston
# 97   98     David Thomas  56998      Phoenix
# 98   99     Olivia Brown  79217      Houston
# 99  100      Laura Davis  62893  San Antonio
#
# [100 rows x 4 columns]

# %%
df.name
# Out:
# 0        John Johnson
# 1       Laura Jackson
# 2        Daniel Brown
# 3         Sarah White
# 4     Michael Jackson
#            ...
# 95      Daniel Taylor
# 96       Olivia Davis
# 97       David Thomas
# 98       Olivia Brown
# 99        Laura Davis
# Name: name, Length: 100, dtype: object

# %%
df['name']
# Out:
# 0        John Johnson
# 1       Laura Jackson
# 2        Daniel Brown
# 3         Sarah White
# 4     Michael Jackson
#            ...
# 95      Daniel Taylor
# 96       Olivia Davis
# 97       David Thomas
# 98       Olivia Brown
# 99        Laura Davis
# Name: name, Length: 100, dtype: object

# %%
df[['id','name']]
# Out:
#      id             name
# 0     1     John Johnson
# 1     2    Laura Jackson
# 2     3     Daniel Brown
# 3     4      Sarah White
# 4     5  Michael Jackson
# ..  ...              ...
# 95   96    Daniel Taylor
# 96   97     Olivia Davis
# 97   98     David Thomas
# 98   99     Olivia Brown
# 99  100      Laura Davis
#
# [100 rows x 2 columns]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1C20-1AA2
#
#  Directory of C:\Users\AI NEXUT IT\Desktop\pandas_6
#
# 10-09-2025  05:29    <DIR>          .
# 10-09-2025  02:17    <DIR>          ..
# 10-09-2025  04:59    <DIR>          .ipynb_checkpoints
# 09-09-2025  04:55         4,744,481 amazon.csv
# 09-09-2025  05:28         1,843,612 COVID-19 pandemic by country and territory - Wikipedia.html
# 09-09-2025  05:28    <DIR>          COVID-19 pandemic by country and territory - Wikipedia_files
# 09-09-2025  05:31             9,380 coviddata.csv
# 09-09-2025  05:32             9,091 edata.html
# 09-09-2025  05:17            11,207 empdata.xlsx
# 09-09-2025  04:58            24,155 employees.json
# 09-09-2025  05:33            65,141 Pandas-1.ipynb
# 10-09-2025  05:15             5,073 temptemptmeptet.xlsx
# 10-09-2025  05:29            43,719 Untitled.ipynb
#                9 File(s)      6,755,859 bytes
#                4 Dir(s)  230,660,034,560 bytes free

# %%
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  ^ Countries which do not report data for a col...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# ...

# %%
df[[col for col in df.columns if col.lower().startswith('c')]]
# Out:
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# 4                               Bosnia and Herzegovina
# ..                                                 ...
# 235                                   Pitcairn Islands
# 236                                            Tokelau
# 237                                        North Korea
# 238                                       Turkmenistan
# 239  ^ Countries which do not report data for a col...
#
#                                                  Cases
# 0                                            778402651
# 1                                              4532707
# 2                                              1338533
# 3                                               352093
# ...

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df
# Out:
#                                             unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  ^ Countries which do not report data for a col...
#
#                                                country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# ...

# %%
df.dtypes
# Out:
# unnamed: 0          object
# country             object
# deaths / million    object
# deaths              object
# cases               object
# dtype: object

# %%
df = pd.read_excel("empdata.xlsx")

# %%
df.dtypes
# Out:
# id         int64
# name      object
# dept      object
# Region    object
# dtype: object

# %%
df['id'] = df['id'].astype(float)

# %%
df
# Out:
#         id    name   dept Region      id1
# 0    434.0  keshav     IT   Pune    434.0
# 1  43423.0  Pratik     HR   Pune  43423.0
# 2  43434.0  Sonali  Admin   Pune  43434.0
# 3  32342.0    Amit     HR   Pune  32342.0
